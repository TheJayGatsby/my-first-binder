# %%
pi
# Out:
# π = 3.1415926535897...

# %%
 a = 22/7
# Out:
# 3.142857142857143

# %%
error = abs(pi-22/7)/pi
# Out:
# 0.0004024994347707008

# %%
println("Erro é aproximadamente ",error*100,"%")
# Out:
# Erro é aproximadamente 0.04024994347707008%
