# %% [markdown]
# # Primeiro teste de notebook julia
#
# Parece que é simples de fazer, mas ainda estou aprendendo.
#
# Coisas a fazer:
#
# - Aprender formatação markdown.
# - Aprender a quebrar e juntar células

# %% [markdown]
# Primeiro vamos definir o valor final alvo (pi) e o valor incial (fração aproximada):

# %%
vf = pi
vi = 22/7
# Out:
# 3.142857142857143

# %% [markdown]
# Agora calculamos o erro em porcentagem da fração que aproxima pi:

# %%
error = abs(pi-22/7)/pi

println("Erro é aproximadamente ",error*100,"%")
# Out:
# Erro é aproximadamente 0.04024994347707008%
